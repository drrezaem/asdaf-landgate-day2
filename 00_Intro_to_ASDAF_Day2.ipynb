# %% [markdown]
# <h1>Introduction to ASDAF - Day 2 Overview</h1>
#
# <h2>Finding and Downloading Data</h2>
#
# Data hub: http://www.asdaf.space/data/
#
# <b>Main Data Sources at ASDAF</b>
#
# - National Map
# - Digital Earth Australia
# - Sentinel Australasia (Copernicus Hub)
# - Australian Ocean Data Network
#
# <h2>Automation</h2>
#
# <b>Sentinel Australasia (Copernicus Hub)</b>
# - Data access through AusCopHub_SearchSara.py command-line tool
# - Data access through the SARA Client Python API
#
# <b>Introduction to Pawsey</b>
# - Available datasets
# - Pawsey accounts for data access
# - Access to data via shell interface "pshell"
# - Navigation through the projects folder
# - Uploading and downloading files
# - Limitations of pshell's basic commands
#
# <b>Introduction to Mediaflux</b>
# - Finding and downloading the data using Mediaflux
# - Issuing Mediaflux commands through pshell
# - Executing Mediaflux commands using the Python API
# - Filtering based on non-spatial attributes
# - Spatial filtering
#
# <h2>Processing the Data</h2>
#
# Revision of Python and Related Frameworks
#
# <b>Python</b>
# - tuples, list and dictionary comprehension
# - ufuncs and broadcasting
#
# <b>Numpy</b>
# - Addition/subtraction/multiplcation/division
# - Calculating an NDVI
# - Logical functions
# - Nodata values, masks, clouds
#
# <b>Rasterio</b>
# - Reading and writing data
# - Stacking datasets
# - Windowed reading/writing to avoid memory problems.
#
# <b>Applications</b>
# - Firescar and burn severity
# - Mosaicking Data
