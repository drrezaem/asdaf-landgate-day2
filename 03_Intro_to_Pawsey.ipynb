# %% [markdown]
# <h1>Introduction to Pawsey</h1>
#
# https://pawsey.org.au/
#
# <b>Applying for a Pawsey account</b><br/>
#
# https://pawsey.org.au/apply/
#
#
# Data portal:
#
# https://support.pawsey.org.au/documentation/display/US/The+Data+Portal
#
# This provides introductory material on pshell, Mediaflux, etc. (more later)
#
# <b>Dashboard to monitor disk usage, etc.</b>
#
# https://data.pawsey.org.au/
#
# <b>Access to data via shell interface "pshell"</b><br/>
#
# https://support.pawsey.org.au/documentation/display/US/Basic+pshell+use
#
# $ ./pshell<br/>
#  === pshell: type 'help' for a list of commands ===<br/>
# pawsey:offline>login<br/>
# Username: mwatson2<br/>
# Password:<br/>
#
# <b>Navigating the projects directory</b><br/><br/>
# pawsey:/projects>pwd<br/>
# Remote: /projects<br/>
# pawsey:/projects>ls<br/>
#
# 1 item, 37 items per page, remote folder: /projects<br/>
# [Folder] WACopernicus<br/><br/>
# pawsey:/projects>cd WACopernicus<br/>
# Remote: /projects/WACopernicus<br/>
# pawsey:/projects/WACopernicus>ls<br/>
# 3 items, 37 items per page, remote folder: /projects/WACopernicus<br/>
# [Folder] Sentinel-1<br/>
# [Folder] Sentinel-2<br/>
# [Folder] Sentinel-3<br/>
#
#
# pawsey:/projects>lpwd<br/>
# Local: /d/mw<br/>
#
# <b>Downloading files</b><br/>
#
# Use the "get" command
#
# <b>Uploading files</b><br/>
#
# Use the "put" command
#
# <b>Deleting files</b><br/>
#
# Use the "rm" command
#
# Similar to FTP commands - fairly limited.
